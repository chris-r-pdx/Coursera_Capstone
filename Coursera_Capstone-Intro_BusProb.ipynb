# %% [markdown]
# ### Applied Data Science Capstone
#
# #### Week 1 - Introduction and Business Problem
# A description of the problem and a discussion of the background. (15 marks)<br>
# A description of the data and how it will be used to solve the problem. (15 marks)

# %% [markdown]
# #### The Problem & Background

# %% [markdown]
# *Is it possible to warn you, given the weather and road conditions, how severe a car accident you could be in?  Would it make you drive more carefully or possible change your travel timing or route?*
#
# The purpose of this project is to attempt to predict the severity of a car accident given certain conditions.
#
# There are several potential applications for this prediction model. As noted above, understanding the potential severity of an accident given certain weather, road and other conditions - before you travel - could impact your travel timing or route.  Insurance companies could incentivize drivers to travel at other times when conditions lead to more severe incidents, or make preliminary determinations of monetary exposure they may have in an accident, prior to physical inspections by insurance adjustors, medical evaluations, etc.
#
# A machine learning model will be used to attempt to solve this problem: predicting the severity of a car accident given certain conditions.
#
# The following process will be followed:
#
# - Data will be collected then explored and visualized to understand its attributes that will be used to train the machine learning model.
#
# - That data will then be prepared for modeling through labeling, transformation, filling missing data, etc.
#
# - Various algorightms and methods will be selected and applied to build the model, including supervised machine learning techniques.
#
# - The model will be be evaluated to ensure the objective is achieved.
#
# - Finally, a report will be developed describing the process and results.

# %% [markdown]
# #### The Data - Overview

# %% [markdown]
# This project will utilize Seattle, WA vehicle accident data from January 1, 2004 through May 20, 2020. Each record in this dataset represents one vehicle accident during this time period.
#
# Each accident has a "severity" rating, which is a code that corresponds to the severity of the collision. Other attributes for each accident are included, such as incident location, weather, light and road conditions at the time of the indident, the number of vehicles involved, whether a pedestrian was involved, etc.
#
# For example, the weather attribute has the following values:
# - Clear
# - Raining
# - Overcast
# - Unknown
# - Snowing
# - Other
# - Fog/Smog/Smoke
# - Sleet/Hail/Freezing Rain
# - Blowing Sand/Dirt
# - Severe Crosswind
# - Partly Cloudy
#
# And the road condition attribute has the following values:
# - Dry
# - Wet
# - Unknown
# - Ice
# - Snow/Slush
# - Other
# - Standing Water
# - Sand/Mud/Dirt
# - Oil
#
# Complete metadata for this dataset is provided <a href='https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Metadata.pdf'>here</a>.
#
# The purpose of this exercise is to develop a model which will predict the "severity" of an accident (the target/dependent variable) based upon other characteristics surrounding the collision (the independent variables).
#
# Not all of these incident attributes will be used in the model.  The remainder of this notebook is devoted to data exploration and making initial determinations of what data appears most useful for the model, what data does not appear useful and should be removed, and other transformations which must take place such as handling missing data, adjusting numerical vs categorical data, and feature engineering.

# %% [markdown]
# #### Data exploration

# %%
# Libraries
import pandas as pd
import numpy as np

# %%
# load the data into a dataframe which had been downloaded locally from:
# https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv

collision_df = pd.read_csv('Data-Collisions.csv')
collision_df.head()
# Out:
# /Users/chrisriper/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (33) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
# 3             1 -122.334803  47.604803         4    1144       1144  3503937
# 4             2 -122.306426  47.545739         5   17700      17700  1807429
#
#     STATUS      ADDRTYPE   INTKEY  ... ROADCOND                LIGHTCOND  \
# 0  Matched  Intersection  37475.0  ...      Wet                 Daylight
# 1  Matched         Block      NaN  ...      Wet  Dark - Street Lights On
# 2  Matched         Block      NaN  ...      Dry                 Daylight
# 3  Matched         Block      NaN  ...      Dry                 Daylight
# 4  Matched  Intersection  34387.0  ...      Wet                 Daylight
#
#   PEDROWNOTGRNT  SDOTCOLNUM SPEEDING ST_COLCODE  \
# 0           NaN         NaN      NaN         10
# 1           NaN   6354039.0      NaN         11
# 2           NaN   4323031.0      NaN         32
# 3           NaN         NaN      NaN         23
# 4           NaN   4028032.0      NaN         10
#
#                                           ST_COLDESC  SEGLANEKEY  \
# 0                                  Entering at angle           0
# 1  From same direction - both going straight - bo...           0
# 2                             One parked--one moving           0
# 3                   From same direction - all others           0
# 4                                  Entering at angle           0
#
#    CROSSWALKKEY  HITPARKEDCAR
# 0             0             N
# 1             0             N
# 2             0             N
# 3             0             N
# 4             0             N
#
# [5 rows x 38 columns]

# %%
# examine column types
collision_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194673 entries, 0 to 194672
# Data columns (total 38 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   SEVERITYCODE    194673 non-null  int64
#  1   X               189339 non-null  float64
#  2   Y               189339 non-null  float64
#  3   OBJECTID        194673 non-null  int64
#  4   INCKEY          194673 non-null  int64
#  5   COLDETKEY       194673 non-null  int64
#  6   REPORTNO        194673 non-null  object
#  7   STATUS          194673 non-null  object
#  8   ADDRTYPE        192747 non-null  object
#  9   INTKEY          65070 non-null   float64
#  10  LOCATION        191996 non-null  object
#  11  EXCEPTRSNCODE   84811 non-null   object
#  12  EXCEPTRSNDESC   5638 non-null    object
#  13  SEVERITYCODE.1  194673 non-null  int64
#  14  SEVERITYDESC    194673 non-null  object
#  15  COLLISIONTYPE   189769 non-null  object
#  16  PERSONCOUNT     194673 non-null  int64
#  17  PEDCOUNT        194673 non-null  int64
#  18  PEDCYLCOUNT     194673 non-null  int64
#  19  VEHCOUNT        194673 non-null  int64
#  20  INCDATE         194673 non-null  object
#  21  INCDTTM         194673 non-null  object
#  22  JUNCTIONTYPE    188344 non-null  object
#  23  SDOT_COLCODE    194673 non-null  int64
#  24  SDOT_COLDESC    194673 non-null  object
#  25  INATTENTIONIND  29805 non-null   object
#  26  UNDERINFL       189789 non-null  object
#  27  WEATHER         189592 non-null  object
#  28  ROADCOND        189661 non-null  object
#  29  LIGHTCOND       189503 non-null  object
#  30  PEDROWNOTGRNT   4667 non-null    object
#  31  SDOTCOLNUM      114936 non-null  float64
#  32  SPEEDING        9333 non-null    object
#  33  ST_COLCODE      194655 non-null  object
#  34  ST_COLDESC      189769 non-null  object
#  35  SEGLANEKEY      194673 non-null  int64
#  36  CROSSWALKKEY    194673 non-null  int64
#  37  HITPARKEDCAR    194673 non-null  object
# dtypes: float64(4), int64(12), object(22)
# memory usage: 56.4+ MB

# %%
'''
Examine some columns which do not appear useful per metadata for prediction
* OBJECTID
* INCKEY
* COLDETKEY
* REPORTNO
* STATUS
* EXCEPTRSNCODE
* EXCEPTRSNDESC
* SEVERITYCODE.1
* SDOTCOLNUM
* ST_COLCODE
* ST_COLDESC
* SEGLANEKEY

'''

collision_df[['OBJECTID','INCKEY','COLDETKEY','REPORTNO','STATUS','EXCEPTRSNCODE','EXCEPTRSNDESC','SEVERITYCODE.1','SDOTCOLNUM','ST_COLCODE','ST_COLDESC','SEGLANEKEY']].head(10)
# Out:
#    OBJECTID  INCKEY  COLDETKEY REPORTNO   STATUS EXCEPTRSNCODE EXCEPTRSNDESC  \
# 0         1    1307       1307  3502005  Matched                         NaN
# 1         2   52200      52200  2607959  Matched           NaN           NaN
# 2         3   26700      26700  1482393  Matched           NaN           NaN
# 3         4    1144       1144  3503937  Matched                         NaN
# 4         5   17700      17700  1807429  Matched           NaN           NaN
# 5         6  320840     322340  E919477  Matched                         NaN
# 6         7   83300      83300  3282542  Matched           NaN           NaN
# 7         9  330897     332397  EA30304  Matched                         NaN
# 8        10   63400      63400  2071243  Matched           NaN           NaN
# 9        12   58600      58600  2072105  Matched           NaN           NaN
#
#    SEVERITYCODE.1  SDOTCOLNUM ST_COLCODE  \
# 0               2         NaN         10
# 1               1   6354039.0         11
# 2               1   4323031.0         32
# 3               1         NaN         23
# 4               2   4028032.0         10
# 5               1         NaN         10
# 6               1   8344002.0         10
# 7               2         NaN          5
# 8               1   6166014.0         32
# 9               2   6079001.0         10
#
#                                           ST_COLDESC  SEGLANEKEY
# 0                                  Entering at angle           0
# 1  From same direction - both going straight - bo...           0
# 2                             One parked--one moving           0
# 3                   From same direction - all others           0
# 4                                  Entering at angle           0
# 5                                  Entering at angle           0
# 6                                  Entering at angle           0
# 7                       Vehicle Strikes Pedalcyclist        6855
# 8                             One parked--one moving           0
# 9                                  Entering at angle           0

# %%
# drop columns that do not appear useful for prediction
collision_df.drop(['OBJECTID','INCKEY','COLDETKEY','REPORTNO','STATUS','EXCEPTRSNCODE','EXCEPTRSNDESC','SEVERITYCODE.1','SDOTCOLNUM','ST_COLCODE','ST_COLDESC','SEGLANEKEY'], axis = 1, inplace = True)

# %%
collision_df.head()
# Out:
#    SEVERITYCODE           X          Y      ADDRTYPE   INTKEY  \
# 0             2 -122.323148  47.703140  Intersection  37475.0
# 1             1 -122.347294  47.647172         Block      NaN
# 2             1 -122.334540  47.607871         Block      NaN
# 3             1 -122.334803  47.604803         Block      NaN
# 4             2 -122.306426  47.545739  Intersection  34387.0
#
#                                       LOCATION  \
# 0                   5TH AVE NE AND NE 103RD ST
# 1   AURORA BR BETWEEN RAYE ST AND BRIDGE WAY N
# 2  4TH AVE BETWEEN SENECA ST AND UNIVERSITY ST
# 3     2ND AVE BETWEEN MARION ST AND MADISON ST
# 4              SWIFT AVE S AND SWIFT AV OFF RP
#
#                      SEVERITYDESC COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  ...  \
# 0                Injury Collision        Angles            2         0  ...
# 1  Property Damage Only Collision     Sideswipe            2         0  ...
# 2  Property Damage Only Collision    Parked Car            4         0  ...
# 3  Property Damage Only Collision         Other            3         0  ...
# 4                Injury Collision        Angles            2         0  ...
#
#                                         SDOT_COLDESC  INATTENTIONIND  \
# 0  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...             NaN
# 1  MOTOR VEHICLE STRUCK MOTOR VEHICLE, LEFT SIDE ...             NaN
# 2       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END             NaN
# 3  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...             NaN
# 4  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...             NaN
#
#   UNDERINFL   WEATHER ROADCOND                LIGHTCOND PEDROWNOTGRNT  \
# 0         N  Overcast      Wet                 Daylight           NaN
# 1         0   Raining      Wet  Dark - Street Lights On           NaN
# 2         0  Overcast      Dry                 Daylight           NaN
# 3         N     Clear      Dry                 Daylight           NaN
# 4         0   Raining      Wet                 Daylight           NaN
#
#   SPEEDING CROSSWALKKEY HITPARKEDCAR
# 0      NaN            0            N
# 1      NaN            0            N
# 2      NaN            0            N
# 3      NaN            0            N
# 4      NaN            0            N
#
# [5 rows x 26 columns]

# %%
'''
SEVERITY
A code that corresponds to the severity of the
collision:
• 3—fatality
• 2b—serious injury
• 2—injury
• 1—prop damage
• 0—unknown
'''
collision_df['SEVERITYCODE'].value_counts()
# Out:
# 1    136485
# 2     58188
# Name: SEVERITYCODE, dtype: int64

# %%
collision_df['ST_COLCODE'].value_counts()
# Out:
# 32    27612
# 10    23427
# 14    16883
# 32    16809
# 10    11247
#       ...
# 54        1
# 43        1
# 43        1
# 87        1
# 60        1
# Name: ST_COLCODE, Length: 115, dtype: int64

# %%
collision_df['COLLISIONTYPE'].value_counts()
# Out:
# Parked Car    47987
# Angles        34674
# Rear Ended    34090
# Other         23703
# Sideswipe     18609
# Left Turn     13703
# Pedestrian     6608
# Cycles         5415
# Right Turn     2956
# Head On        2024
# Name: COLLISIONTYPE, dtype: int64

# %%
print("Earliest incident date: ", collision_df['INCDATE'].min())
print("Latest incident date: ", collision_df['INCDATE'].max())
# Out:
# Earliest incident date:  2004/01/01 00:00:00+00
# Latest incident date:  2020/05/20 00:00:00+00

# %%
# Weather
collision_df['WEATHER'].value_counts()
# Out:
# Clear                       111135
# Raining                      33145
# Overcast                     27714
# Unknown                      15091
# Snowing                        907
# Other                          832
# Fog/Smog/Smoke                 569
# Sleet/Hail/Freezing Rain       113
# Blowing Sand/Dirt               56
# Severe Crosswind                25
# Partly Cloudy                    5
# Name: WEATHER, dtype: int64

# %%
# Road Conditions
collision_df['ROADCOND'].value_counts()
# Out:
# Dry               124510
# Wet                47474
# Unknown            15078
# Ice                 1209
# Snow/Slush          1004
# Other                132
# Standing Water       115
# Sand/Mud/Dirt         75
# Oil                   64
# Name: ROADCOND, dtype: int64

# %%
# Light Conditions
collision_df['LIGHTCOND'].value_counts()
# Out:
# Daylight                    116137
# Dark - Street Lights On      48507
# Unknown                      13473
# Dusk                          5902
# Dawn                          2502
# Dark - No Street Lights       1537
# Dark - Street Lights Off      1199
# Other                          235
# Dark - Unknown Lighting         11
# Name: LIGHTCOND, dtype: int64

# %%
# Correlation matrix

collision_df.corr()
# Out:
#                 SEVERITYCODE         X         Y  OBJECTID    INCKEY  \
# SEVERITYCODE        1.000000  0.010309  0.017737  0.020131  0.022065
# X                   0.010309  1.000000 -0.160262  0.009956  0.010309
# Y                   0.017737 -0.160262  1.000000 -0.023848 -0.027396
# OBJECTID            0.020131  0.009956 -0.023848  1.000000  0.946383
# INCKEY              0.022065  0.010309 -0.027396  0.946383  1.000000
# COLDETKEY           0.022079  0.010300 -0.027415  0.945837  0.999996
# INTKEY              0.006553  0.120754 -0.114935  0.046929  0.048524
# SEVERITYCODE.1      1.000000  0.010309  0.017737  0.020131  0.022065
# PERSONCOUNT         0.130949  0.012887 -0.013850 -0.062333 -0.061500
# PEDCOUNT            0.246338  0.011304  0.010178  0.024604  0.024918
# PEDCYLCOUNT         0.214218 -0.001752  0.026304  0.034432  0.031342
# VEHCOUNT           -0.054686 -0.012168  0.017058 -0.094280 -0.107528
# SDOT_COLCODE        0.188905  0.010904 -0.019694 -0.037094 -0.027617
# SDOTCOLNUM          0.004226 -0.001016 -0.006958  0.969276  0.990571
# SEGLANEKEY          0.104276 -0.001618  0.004618  0.028076  0.019701
# CROSSWALKKEY        0.175093  0.013586  0.009508  0.056046  0.048179
#
#                 COLDETKEY    INTKEY  SEVERITYCODE.1  PERSONCOUNT  PEDCOUNT  \
# SEVERITYCODE     0.022079  0.006553        1.000000     0.130949  0.246338
# X                0.010300  0.120754        0.010309     0.012887  0.011304
# Y               -0.027415 -0.114935        0.017737    -0.013850  0.010178
# OBJECTID         0.945837  0.046929        0.020131    -0.062333  0.024604
# INCKEY           0.999996  0.048524        0.022065    -0.061500  0.024918
# COLDETKEY        1.000000  0.048499        0.022079    -0.061403  0.024914
# INTKEY           0.048499  1.000000        0.006553     0.001886 -0.004784
# SEVERITYCODE.1   0.022079  0.006553        1.000000     0.130949  0.246338
# PERSONCOUNT     -0.061403  0.001886        0.130949     1.000000 -0.023464
# PEDCOUNT         0.024914 -0.004784        0.246338    -0.023464  1.000000
# PEDCYLCOUNT      0.031296  0.000531        0.214218    -0.038809 -0.016920
# VEHCOUNT        -0.107598 -0.012929       -0.054686     0.380523 -0.261285
# SDOT_COLCODE    -0.027461  0.007114        0.188905    -0.128960  0.260393
# SDOTCOLNUM       0.990571  0.032604        0.004226     0.011784  0.021461
# SEGLANEKEY       0.019586 -0.010510        0.104276    -0.021383  0.001810
# CROSSWALKKEY     0.048063  0.018420        0.175093    -0.032258  0.565326
#
#                 PEDCYLCOUNT  VEHCOUNT  SDOT_COLCODE  SDOTCOLNUM  SEGLANEKEY  \
# SEVERITYCODE       0.214218 -0.054686      0.188905    0.004226    0.104276
# X                 -0.001752 -0.012168      0.010904   -0.001016   -0.001618
# Y                  0.026304  0.017058     -0.019694   -0.006958    0.004618
# OBJECTID           0.034432 -0.094280     -0.037094    0.969276    0.028076
# INCKEY             0.031342 -0.107528     -0.027617    0.990571    0.019701
# COLDETKEY          0.031296 -0.107598     -0.027461    0.990571    0.019586
# INTKEY             0.000531 -0.012929      0.007114    0.032604   -0.010510
# SEVERITYCODE.1     0.214218 -0.054686      0.188905    0.004226    0.104276
# PERSONCOUNT       -0.038809  0.380523     -0.128960    0.011784   -0.021383
# PEDCOUNT          -0.016920 -0.261285      0.260393    0.021461    0.001810
# PEDCYLCOUNT        1.000000 -0.253773      0.382521    0.034593    0.453657
# VEHCOUNT          -0.253773  1.000000     -0.365814   -0.023813   -0.122941
# SDOT_COLCODE       0.382521 -0.365814      1.000000   -0.041084    0.206835
# SDOTCOLNUM         0.034593 -0.023813     -0.041084    1.000000    0.066449
# SEGLANEKEY         0.453657 -0.122941      0.206835    0.066449    1.000000
# CROSSWALKKEY       0.109820 -0.200526      0.189518    0.086228   -0.003422
#
#                 CROSSWALKKEY
# SEVERITYCODE        0.175093
# X                   0.013586
# Y                   0.009508
# OBJECTID            0.056046
# INCKEY              0.048179
# COLDETKEY           0.048063
# INTKEY              0.018420
# SEVERITYCODE.1      0.175093
# PERSONCOUNT        -0.032258
# PEDCOUNT            0.565326
# PEDCYLCOUNT         0.109820
# VEHCOUNT           -0.200526
# SDOT_COLCODE        0.189518
# SDOTCOLNUM          0.086228
# SEGLANEKEY         -0.003422
# CROSSWALKKEY        1.000000

# %%
# Visualization of the correlation matrix

import seaborn as sn
import matplotlib.pyplot as plt

sn.heatmap(collision_df.corr(), annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-04a1ad3db126> in <module>()
#       1 # Visualization of the correlation matrix
#       2
# ----> 3 import seaborn as sn
#       4 import matplotlib.pyplot as plt
#       5
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/__init__.py in <module>()
#       4
#       5 # Import seaborn objects
# ----> 6 from .rcmod import *
#       7 from .utils import *
#       8 from .palettes import *
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/rcmod.py in <module>()
#       5 import matplotlib as mpl
#       6 from cycler import cycler
# ----> 7 from . import palettes, _orig_rc_params
#       8
#       9
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/palettes.py in <module>()
#       7 from .external import husl
#       8
# ----> 9 from .utils import desaturate, set_hls_values, get_color_cycle
#      10 from .colors import xkcd_rgb, crayons
#      11
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/utils.py in <module>()
#       4
#       5 import numpy as np
# ----> 6 from scipy import stats
#       7 import pandas as pd
#       8 import matplotlib as mpl
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/stats/__init__.py in <module>()
#     386
#     387 """
# --> 388 from .stats import *
#     389 from .distributions import *
#     390 from .morestats import *
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py in <module>()
#     172 from numpy import array, asarray, ma
#     173
# --> 174 from scipy.spatial.distance import cdist
#     175 from scipy.ndimage import measurements
#     176 from scipy._lib._util import (_lazywhere, check_random_state, MapWrapper,
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/spatial/__init__.py in <module>()
#      96 from .kdtree import *
#      97 from .ckdtree import *
# ---> 98 from .qhull import *
#      99 from ._spherical_voronoi import SphericalVoronoi
#     100 from ._plotutils import *
#
# ImportError: dlopen(/Users/chrisriper/anaconda3/lib/python3.6/site-packages/scipy/spatial/qhull.cpython-36m-darwin.so, 2): Library not loaded: @rpath/libopenblas.dylib
#   Referenced from: /Users/chrisriper/anaconda3/lib/python3.6/site-packages/scipy/spatial/qhull.cpython-36m-darwin.so
#   Reason: image not found

# %%
corr = collision_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow0_col0,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow0_col7,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow1_col1,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow2_col2,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow3_col3,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow4_col4,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow4_col5,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow5_col4,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow5_col5,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow6_col6,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow7_col0,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow7_col7,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow8_col8,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow9_col9,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow10_col10,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow11_col11,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow12_col12,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow13_col13,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow14_col14,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow15_col15{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow0_col1,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow3_col1,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow3_col6,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow4_col1,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow4_col6,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow5_col1,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow5_col6,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow7_col1,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow9_col1,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow9_col2,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow12_col1,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow15_col2{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow0_col2,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow7_col2,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow11_col2{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow0_col3,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow2_col8,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow7_col3,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow8_col6,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow10_col6,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow14_col13{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow0_col4,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow0_col5,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow2_col14,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow4_col2,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow5_col2,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow6_col8,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow7_col4,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow7_col5,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow14_col4,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow14_col5{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow0_col6,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow1_col4,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow1_col5,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow1_col14,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow7_col6,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow9_col3,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow15_col14{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow0_col8,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow0_col11,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow3_col9,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow3_col10,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow4_col9,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow4_col10,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow5_col9,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow5_col10,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow7_col8,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow7_col11,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow13_col10{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow0_col9,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow0_col12,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow7_col9,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow7_col12{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow0_col10,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow7_col10{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow0_col13,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow7_col13{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow0_col14,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow1_col10,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow6_col10,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow7_col14{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow0_col15,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow7_col15{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow1_col0,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow1_col7,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow3_col8,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow4_col8,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow5_col8,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow9_col13{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow1_col2,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow2_col1,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow2_col6,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow11_col0,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow11_col3,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow11_col4,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow11_col5,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow11_col7,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow11_col9,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow11_col10,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow11_col12,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow11_col14,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow11_col15,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow12_col8,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow12_col11,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow12_col13{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow1_col3,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow14_col8{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow1_col6,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow3_col15{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow1_col8,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow4_col14,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow5_col14,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow8_col2,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow10_col4,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow10_col5,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow11_col1{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow1_col9,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow2_col9,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow15_col0,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow15_col7{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow1_col11,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow6_col11,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow10_col15{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow1_col12{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow1_col13{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow1_col15,#T_acf97f30_f8a1_11ea_9f31_d4619d1d58eerow8_col0,#T_acf97f30_f
